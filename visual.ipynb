# %%
import h5py
import numpy as np
import gzip
from matplotlib import pyplot as plt
import nibabel as nib

filename = "../data/Synapse/test_vol_h5/case0036.npy.h5"
gt = "../predictions/TU_Synapse224/TU_pretrain_R50-ViT-B_16_skip3_epo150_bs24_224/case0008_gt.nii.gz"
img = "../predictions/TU_Synapse224/TU_pretrain_R50-ViT-B_16_skip3_epo150_bs24_224/case0008_img.nii.gz"
pred = "../predictions/TU_Synapse224/TU_pretrain_R50-ViT-B_16_skip3_epo150_bs24_224/case0008_pred.nii.gz"
trainfile = "../data/Synapse/train_npz/case0026_slice100.npz"

image = nib.load(img)
im = np.array(image.dataobj)
print(im.shape)
plt.imshow(im[:,:,100], interpolation='nearest')
plt.show()


predict = nib.load(pred)
pre = np.array(predict.dataobj)
print(pre.shape)
plt.imshow(pre[:,:,100], interpolation='nearest')
plt.show()


ground = nib.load(gt)
gro = np.array(ground.dataobj)
print(gro.shape)
plt.imshow(gro[:,:,100], interpolation='nearest')
plt.show()
# Out:
# (512, 512, 148)
# (512, 512, 148)
# (512, 512, 148)
# ...
